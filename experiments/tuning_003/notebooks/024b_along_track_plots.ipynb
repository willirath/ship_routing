# %% [markdown]
# # Along-Track Cost Decomposition — Plots
#
# Loads per-leg data from `024_best_routes_per_leg_costs.parquet` (produced by 024a)
# and plots along-track cost components and current effects.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

BIN_H = 12
BIN_S = BIN_H * 3600

# %%
df_all_legs = pd.read_parquet("../results/024_best_routes_per_leg_costs.parquet")
print(f"Loaded {len(df_all_legs)} legs")

# Bin legs into regular intervals, sum energy per bin, divide by bin duration
df_all_legs["time_bin"] = (df_all_legs.cum_time_h // BIN_H) * BIN_H + BIN_H / 2

energy_cols = [
    "cost_calm", "cost_waves", "cost_wind", "cost_total",
    "delta_current_on_calm", "delta_current_on_waves",
    "delta_current_on_wind", "delta_current_total",
]
group_cols = ["month", "direction", "speed", "filename", "time_bin"]

df_binned = df_all_legs.groupby(group_cols)[energy_cols].sum().reset_index()
for col in energy_cols:
    df_binned[f"{col}_gw"] = df_binned[col] / BIN_S / 1e9

print(f"Binned to {len(df_binned)} bins ({BIN_H}h)")
# Out:
# Loaded 4262 legs
# Binned to 2052 bins (12h)

# %% [markdown]
# ## Verify per-leg sums match route-level values from 024a

# %%
# Sum per-leg energy back to route level
check_cols = ["cost_calm", "cost_waves", "cost_wind", "cost_total",
              "delta_current_on_calm", "delta_current_on_waves",
              "delta_current_on_wind", "delta_current_total"]
leg_sums = (
    df_all_legs.groupby(["month", "direction", "speed", "filename"])[check_cols]
    .sum()
    .reset_index()
    .rename(columns={"speed": "journey_speed_knots"})
)

# Load route-level values saved by 024a
route_keys = pd.read_parquet("../results/024_best_route_keys.parquet")

# Merge and compare (route_keys may not have delta_current_on_wind yet)
merged = leg_sums.merge(
    route_keys,
    on=["month", "direction", "journey_speed_knots", "filename"],
    suffixes=("_legs", "_route"),
)
print(f"Matched {len(merged)}/{len(route_keys)} routes")

compare_cols = [c for c in check_cols if f"{c}_route" in merged.columns or c in route_keys.columns]
for col in compare_cols:
    legs_col = f"{col}_legs" if f"{col}_legs" in merged.columns else col
    route_col = f"{col}_route" if f"{col}_route" in merged.columns else None
    if route_col is None or route_col not in merged.columns:
        continue
    diff = (merged[legs_col] - merged[route_col]).abs()
    rel = diff / merged[route_col].abs().clip(lower=1)
    print(f"{col}: max abs diff = {diff.max():.2e}, max rel diff = {rel.max():.2e}")
# Out:
# Matched 72/72 routes
# cost_calm: max abs diff = 1.03e-02, max rel diff = 5.02e-15
# cost_waves: max abs diff = 1.86e-02, max rel diff = 3.50e-15
# cost_wind: max abs diff = 5.80e-04, max rel diff = 2.51e-15
# cost_total: max abs diff = 2.93e-02, max rel diff = 3.53e-15
# delta_current_on_calm: max abs diff = 2.81e-03, max rel diff = 2.74e-13
# delta_current_on_waves: max abs diff = 5.19e-03, max rel diff = 2.80e-13
# delta_current_total: max abs diff = 1.81e+09, max rel diff = 7.54e-03

# %%
CASES = [
    {"month": "Aug", "direction": "eastward", "speed": 8, "label": "Aug E 8kn (current)"},
    {"month": "Jul", "direction": "eastward", "speed": 8, "label": "Jul E 8kn (current+mixed)"},
    {"month": "Aug", "direction": "westward", "speed": 12, "label": "Aug W 12kn (calm)"},
    {"month": "Oct", "direction": "westward", "speed": 10, "label": "Oct W 10kn (wave detour)"},
    {"month": "Jan", "direction": "eastward", "speed": 8, "label": "Jan E 8kn (wave+current)"},
]

# %% [markdown]
# ## Along-track decomposition per case
#
# Each row is one representative case. Columns:
# 1. Cost component power (stacked bars)
# 2. Cumulative cost component energy (lines)
# 3. Current effect power (stacked bars)
# 4. Cumulative current effect energy (lines)

# %%
ROW_LABELS = ["Component (GW)", "Current effect (GW)",
              "Cumul. component (GJ)", "Cumul. current effect (GJ)"]

BIN_WIDTH = BIN_H * 0.8

fig, axes = plt.subplots(4, len(CASES), figsize=(4 * len(CASES), 9), sharex=False)

# Share y per row
for r in range(4):
    for j in range(1, len(CASES)):
        axes[r, j].sharey(axes[r, 0])

for j, case in enumerate(CASES):
    df_case = df_binned[
        (df_binned.month == case["month"])
        & (df_binned.direction == case["direction"])
        & (df_binned.speed == case["speed"])
    ].sort_values("time_bin")
    x = df_case.time_bin.values

    calm = df_case.cost_calm_gw.values
    waves = df_case.cost_waves_gw.values
    wind = df_case.cost_wind_gw.values
    dc = df_case.delta_current_on_calm_gw.values
    dw = df_case.delta_current_on_waves_gw.values
    dwi = df_case.delta_current_on_wind_gw.values

    # Row 0: cost component power
    ax = axes[0, j]
    ax.bar(x, calm, width=BIN_WIDTH, label="calm")
    ax.bar(x, waves, bottom=calm, width=BIN_WIDTH, label="waves")
    ax.bar(x, wind, bottom=calm + waves, width=BIN_WIDTH, label="wind")

    # Row 1: current effect power
    ax = axes[1, j]
    ax.bar(x, dc, width=BIN_WIDTH, label="on calm")
    ax.bar(x, dw, bottom=dc, width=BIN_WIDTH, label="on waves")
    ax.bar(x, dwi, bottom=dc + dw, width=BIN_WIDTH, label="on wind")

    # Row 2: cumulative cost component energy
    ax = axes[2, j]
    cum_calm = np.cumsum(df_case.cost_calm.values) / 1e9
    cum_waves = np.cumsum(df_case.cost_waves.values) / 1e9
    cum_wind = np.cumsum(df_case.cost_wind.values) / 1e9
    ax.step(x, cum_calm, where="mid", label="calm")
    ax.step(x, cum_waves, where="mid", label="waves")
    ax.step(x, cum_wind, where="mid", label="wind")
    ax.step(x, cum_calm + cum_waves + cum_wind, where="mid", color="k", linewidth=1.5, label="total")
    ax.set_yscale("log")

    # Row 3: cumulative current effect energy
    ax = axes[3, j]
    cc = np.cumsum(df_case.delta_current_on_calm.values) / 1e9
    cw = np.cumsum(df_case.delta_current_on_waves.values) / 1e9
    cwi = np.cumsum(df_case.delta_current_on_wind.values) / 1e9
    ax.step(x, cc, where="mid", label="on calm")
    ax.step(x, cw, where="mid", label="on waves")
    ax.step(x, cwi, where="mid", label="on wind")
    ax.step(x, cc + cw + cwi, where="mid", color="k", linewidth=1.5, label="total")
    ax.set_yscale("symlog", linthresh=1e-1)

    # Column title
    axes[0, j].set_title(case["label"])

    # Legend on first column only
    if j == 0:
        for r in range(4):
            ncol = 2 if r >= 2 else 1
            axes[r, j].legend(ncol=ncol)

# Row labels, grid, x-axis label
for r, label in enumerate(ROW_LABELS):
    for j in range(len(CASES)):
        axes[r, j].grid(True)
    axes[r, 0].set_ylabel(label)
for j in range(len(CASES)):
    axes[-1, j].set_xlabel("Time (h)")

plt.tight_layout()
plt.savefig("../figures/024_along_track_decomposition.png")
plt.savefig("../figures/024_along_track_decomposition.pdf")
