# %% [markdown]
# # Hyper Param Cost Violins
#
# - hyper params
#   - population + M_offspring * N_crossover
#   - N_mut * W * D * gen
#   - population
#   - generations

# %%
from pathlib import Path
from tqdm.auto import tqdm

import pandas as pd
import geopandas as gpd
import numpy as np
from matplotlib import pyplot as plt
import cartopy
import cmocean
import xarray as xr
import seaborn as sns

from load_tuning_results import (
    load_results,
    get_forcing_df,
    get_seed_routes_gdf,
    filter_suspicious_routes,
    add_derived_features,
)

import warnings
warnings.filterwarnings("ignore")

# %%
# parameters

# results dataframe from
gpq_file = "../results/results_prelim.geoparquet"

# %%
gdf = gpd.read_parquet(gpq_file)
gdf = add_derived_features(gdf)
gdf = filter_suspicious_routes(gdf)
gdf
# Out:
# 0.37% suspicious routes
#                             hyper_population_size  hyper_random_seed  \
# filename
# result:0000:seed3895092605                  128.0       3.895093e+09
# result:0000:seed3895092605                  128.0       3.895093e+09
# result:0001:seed1649728346                  256.0       1.649728e+09
# result:0001:seed1649728346                  256.0       1.649728e+09
# result:0002:seed3030206584                  128.0       3.030207e+09
# ...                                           ...                ...
# result:3997:seed3352588423                   64.0       3.352588e+09
# result:3998:seed2264517074                  128.0       2.264517e+09
# result:3998:seed2264517074                  128.0       2.264517e+09
# result:3999:seed3706512598                   64.0       3.706513e+09
# result:3999:seed3706512598                   64.0       3.706513e+09
#
#                             hyper_selection_acceptance_rate_warmup  \
# filename
# result:0000:seed3895092605                                     0.3
# result:0000:seed3895092605                                     0.3
# result:0001:seed1649728346                                     0.3
# result:0001:seed1649728346                                     0.3
# result:0002:seed3030206584                                     0.3
# ...                                                            ...
# result:3997:seed3352588423                                     0.3
# result:3998:seed2264517074                                     0.3
# result:3998:seed2264517074                                     0.3
# result:3999:seed3706512598                                     0.3
# result:3999:seed3706512598                                     0.3
#
#                             hyper_mutation_width_fraction_warmup  \
# filename
# result:0000:seed3895092605                                  0.99
# result:0000:seed3895092605                                  0.99
# result:0001:seed1649728346                                  0.99
# result:0001:seed1649728346                                  0.99
# result:0002:seed3030206584                                  0.99
# ...                                                          ...
# result:3997:seed3352588423                                  0.99
# result:3998:seed2264517074                                  0.99
# result:3998:seed2264517074                                  0.99
# result:3999:seed3706512598                                  0.99
# result:3999:seed3706512598                                  0.99
#
#                             hyper_mutation_displacement_fraction_warmup  \
# filename
# result:0000:seed3895092605                                         0.10
# result:0000:seed3895092605                                         0.10
# result:0001:seed1649728346                                         0.10
# result:0001:seed1649728346                                         0.10
# result:0002:seed3030206584                                         0.25
# ...                                                                 ...
# result:3997:seed3352588423                                         0.25
# result:3998:seed2264517074                                         0.10
# result:3998:seed2264517074                                         0.10
# result:3999:seed3706512598                                         0.10
# result:3999:seed3706512598                                         0.10
#
#                             hyper_generations  hyper_offspring_size  \
# filename
# result:0000:seed3895092605                2.0                   4.0
# result:0000:seed3895092605                2.0                   4.0
# result:0001:seed1649728346                4.0                   4.0
# result:0001:seed1649728346                4.0                   4.0
# result:0002:seed3030206584                2.0                   4.0
# ...                                       ...                   ...
# result:3997:seed3352588423                1.0                   4.0
# result:3998:seed2264517074                1.0                   4.0
# result:3998:seed2264517074                1.0                   4.0
# result:3999:seed3706512598                1.0                   4.0
# result:3999:seed3706512598                1.0                   4.0
#
#                             hyper_crossover_rounds  hyper_selection_quantile  \
# filename
# result:0000:seed3895092605                     1.0                      0.10
# result:0000:seed3895092605                     1.0                      0.10
# result:0001:seed1649728346                     2.0                      0.25
# result:0001:seed1649728346                     2.0                      0.25
# result:0002:seed3030206584                     1.0                      0.10
# ...                                            ...                       ...
# result:3997:seed3352588423                     1.0                      0.25
# result:3998:seed2264517074                     0.0                      0.10
# result:3998:seed2264517074                     0.0                      0.10
# result:3999:seed3706512598                     0.0                      0.10
# result:3999:seed3706512598                     0.0                      0.10
#
#                             hyper_selection_acceptance_rate  ...  \
# filename                                                     ...
# result:0000:seed3895092605                             0.00  ...
# result:0000:seed3895092605                             0.00  ...
# result:0001:seed1649728346                             0.00  ...
# result:0001:seed1649728346                             0.00  ...
# result:0002:seed3030206584                             0.25  ...
# ...                                                     ...  ...
# result:3997:seed3352588423                             0.25  ...
# result:3998:seed2264517074                             0.00  ...
# result:3998:seed2264517074                             0.00  ...
# result:3999:seed3706512598                             0.00  ...
# result:3999:seed3706512598                             0.00  ...
#
#                             forcing_scenario_name  \
# filename
# result:0000:seed3895092605               baseline
# result:0000:seed3895092605               baseline
# result:0001:seed1649728346               baseline
# result:0001:seed1649728346               baseline
# result:0002:seed3030206584               baseline
# ...                                           ...
# result:3997:seed3352588423               no_winds
# result:3998:seed2264517074               no_winds
# result:3998:seed2264517074               no_winds
# result:3999:seed3706512598               no_winds
# result:3999:seed3706512598               no_winds
#
#                                                         forcing_currents_path  \
# filename
# result:0000:seed3895092605  data_large/cmems_mod_glo_phy_my_0.083deg_P1D-m...
# result:0000:seed3895092605  data_large/cmems_mod_glo_phy_my_0.083deg_P1D-m...
# result:0001:seed1649728346  data_large/cmems_mod_glo_phy_my_0.083deg_P1D-m...
# result:0001:seed1649728346  data_large/cmems_mod_glo_phy_my_0.083deg_P1D-m...
# result:0002:seed3030206584  data_large/cmems_mod_glo_phy_my_0.083deg_P1D-m...
# ...                                                                       ...
# result:3997:seed3352588423  data_large/cmems_mod_glo_phy_my_0.083deg_P1D-m...
# result:3998:seed2264517074  data_large/cmems_mod_glo_phy_my_0.083deg_P1D-m...
# result:3998:seed2264517074  data_large/cmems_mod_glo_phy_my_0.083deg_P1D-m...
# result:3999:seed3706512598  data_large/cmems_mod_glo_phy_my_0.083deg_P1D-m...
# result:3999:seed3706512598  data_large/cmems_mod_glo_phy_my_0.083deg_P1D-m...
#
#                                                            forcing_waves_path  \
# filename
# result:0000:seed3895092605  data_large/cmems_mod_glo_wav_my_0.2deg_PT3H-i_...
# result:0000:seed3895092605  data_large/cmems_mod_glo_wav_my_0.2deg_PT3H-i_...
# result:0001:seed1649728346  data_large/cmems_mod_glo_wav_my_0.2deg_PT3H-i_...
# result:0001:seed1649728346  data_large/cmems_mod_glo_wav_my_0.2deg_PT3H-i_...
# result:0002:seed3030206584  data_large/cmems_mod_glo_wav_my_0.2deg_PT3H-i_...
# ...                                                                       ...
# result:3997:seed3352588423  data_large/cmems_mod_glo_wav_my_0.2deg_PT3H-i_...
# result:3998:seed2264517074  data_large/cmems_mod_glo_wav_my_0.2deg_PT3H-i_...
# result:3998:seed2264517074  data_large/cmems_mod_glo_wav_my_0.2deg_PT3H-i_...
# result:3999:seed3706512598  data_large/cmems_mod_glo_wav_my_0.2deg_PT3H-i_...
# result:3999:seed3706512598  data_large/cmems_mod_glo_wav_my_0.2deg_PT3H-i_...
#
#                                                            forcing_winds_path  \
# filename
# result:0000:seed3895092605  data_large/cmems_obs-wind_glo_phy_my_l4_0.125d...
# result:0000:seed3895092605  data_large/cmems_obs-wind_glo_phy_my_l4_0.125d...
# result:0001:seed1649728346  data_large/cmems_obs-wind_glo_phy_my_l4_0.125d...
# result:0001:seed1649728346  data_large/cmems_obs-wind_glo_phy_my_l4_0.125d...
# result:0002:seed3030206584  data_large/cmems_obs-wind_glo_phy_my_l4_0.125d...
# ...                                                                       ...
# result:3997:seed3352588423                                                NaN
# result:3998:seed2264517074                                                NaN
# result:3998:seed2264517074                                                NaN
# result:3999:seed3706512598                                                NaN
# result:3999:seed3706512598                                                NaN
#
#                             diversity_cost_q75_25_rms  \
# filename
# result:0000:seed3895092605               2.248120e+11
# result:0000:seed3895092605               2.248120e+11
# result:0001:seed1649728346               1.018314e+14
# result:0001:seed1649728346               1.018314e+14
# result:0002:seed3030206584               4.047755e+13
# ...                                               ...
# result:3997:seed3352588423               0.000000e+00
# result:3998:seed2264517074               2.325568e+10
# result:3998:seed2264517074               2.325568e+10
# result:3999:seed3706512598               3.506581e+10
# result:3999:seed3706512598               3.506581e+10
#
#                             diversity_cost_q50_00_rms  hyper_num_individuals  \
# filename
# result:0000:seed3895092605               3.436609e+11                  256.0
# result:0000:seed3895092605               3.436609e+11                  256.0
# result:0001:seed1649728346               1.480951e+14                 1024.0
# result:0001:seed1649728346               1.480951e+14                 1024.0
# result:0002:seed3030206584               1.783403e+13                  256.0
# ...                                               ...                    ...
# result:3997:seed3352588423               4.429708e+07                   64.0
# result:3998:seed2264517074               6.256184e+10                  128.0
# result:3998:seed2264517074               6.256184e+10                  128.0
# result:3999:seed3706512598               1.408754e+11                   64.0
# result:3999:seed3706512598               1.408754e+11                   64.0
#
#                             journey_duration     seed_cost  \
# filename
# result:0000:seed3895092605  11 days 10:10:42  5.926383e+12
# result:0000:seed3895092605  11 days 10:10:42  5.926383e+12
# result:0001:seed1649728346  17 days 03:16:03  3.604302e+14
# result:0001:seed1649728346  17 days 03:16:03  3.604302e+14
# result:0002:seed3030206584  13 days 17:00:51  7.524805e+13
# ...                                      ...           ...
# result:3997:seed3352588423  17 days 03:16:03  1.424118e+13
# result:3998:seed2264517074  11 days 10:10:42  6.351398e+12
# result:3998:seed2264517074  11 days 10:10:42  6.351398e+12
# result:3999:seed3706512598  11 days 10:10:42  6.996661e+12
# result:3999:seed3706512598  11 days 10:10:42  6.996661e+12
#
#                             elite_speed_og_mps_average
# filename
# result:0000:seed3895092605                    6.446294
# result:0000:seed3895092605                    6.446294
# result:0001:seed1649728346                    4.551052
# result:0001:seed1649728346                    4.551052
# result:0002:seed3030206584                    5.326478
# ...                                                ...
# result:3997:seed3352588423                    4.115572
# result:3998:seed2264517074                    6.186218
# result:3998:seed2264517074                    6.186218
# result:3999:seed3706512598                    6.182570
# result:3999:seed3706512598                    6.182570
#
# [354508 rows x 56 columns]

# %%
_gdf = gdf.where(
       (gdf.hyper_hazard_penalty_multiplier == 0)
       & (gdf.journey_speed_knots == 12.0)
).dropna(how="all")

# %%
_gdf = _gdf.assign(
    hyper_mu_plus_lambda=(
        _gdf.hyper_population_size 
        + _gdf.hyper_offspring_size * _gdf.hyper_crossover_rounds
    ).astype("category"),
    hyper_mut_step_size=(
        _gdf.hyper_mutation_iterations 
        * _gdf.hyper_mutation_width_fraction
        * _gdf.hyper_mutation_displacement_fraction
        * _gdf.hyper_generations.astype(int)
    ).astype("category"),
    hyper_mutation_iterations=_gdf.hyper_mutation_iterations.astype("category"),
    hyper_crossover_rounds=_gdf.hyper_crossover_rounds.astype("category"),
)

# %%
_gdf.elite_cost_relative.max()
# Out:
# np.float64(0.9998280716183725)

# %%
__gdf = _gdf[                                                                                                       
    _gdf['elite_cost_relative'] 
    <= _gdf.groupby([
        "hyper_generations",                                                                                       
        "hyper_population_size",                                                                                   
        "forcing_scenario_name",                                                                                   
        "hyper_enable_adaptation",                                                                                 
    ])['elite_cost_relative'].transform(lambda x: x.quantile(.9))                                                
]

# %%
sns.set_context("paper", font_scale=2.0)
sns.set_style("whitegrid")
g = sns.catplot(
    data=__gdf,
    y="elite_cost_relative",
    x="hyper_generations",
    # x="journey_name",
    col="hyper_population_size",
    row="forcing_scenario_name",
    hue="hyper_enable_adaptation",
    kind="violin",
    cut=0, 
    inner="quartiles",
    palette="Dark2",
    aspect=1.5,
    margin_titles=True,
)
g.set_titles(col_template="population {col_name}", row_template="{row_name}")
sns.move_legend(                                                                                                   
    g,                                                                                                             
    bbox_to_anchor=(0.85, 0.3), 
    loc='lower right',    
    ncol=2,                                                                                         
    frameon=True                                                                                                   
)
g.fig.suptitle("No Hazards, 12 knots")
g.fig.tight_layout()
g.fig.savefig("../figures/030_hyper_param_cost_violins.pdf", dpi=200)
g.fig.savefig("../figures/030_hyper_param_cost_violins.png", dpi=200)

# %%
sns.set_context("paper", font_scale=2.0)
sns.set_style("whitegrid")
g = sns.catplot(
    data=__gdf,
    y="runtime_seconds",
    hue="hyper_generations",
    x="hyper_population_size",
    kind="box",
    palette="Dark2",
    aspect=1.5,
    margin_titles=True,
) 
g.fig.suptitle("No Hazards, 12 knots")
# g.fig.tight_layout()
g.fig.savefig("../figures/030_hyper_param_runtime_boxes.pdf", dpi=200)
g.fig.savefig("../figures/030_hyper_param_runtime_boxes.png", dpi=200)
